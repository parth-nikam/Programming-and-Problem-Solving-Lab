# %% [markdown]
# # Parth Nikam | PRN: - 20070123120 | E&TC - B1

# %% [markdown]
# # While Loop Sum of Digits

# %% [markdown]
# # Code

# %%
x=int(input("Enter the number-")) 

sum=0
while x>0:
    b=x%10    
    sum=sum+b
    x=x//10
print('The sum is-',sum)
# Out:
# Enter the number-74569
# The sum is- 31

# %% [markdown]
# # Algorithm

# %% [raw]
# 1. START.
# 2. Input a value.
# 3. Break the number.
# 4. Add the digits.
# 5. Print Sum.
# 6. STOP.

# %% [markdown]
# # Flowchart

# %% [markdown]
# ![While%20Loop.png](attachment:While%20Loop.png)
