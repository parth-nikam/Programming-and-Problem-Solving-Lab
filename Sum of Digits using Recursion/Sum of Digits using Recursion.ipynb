# %% [markdown]
# # Parth Nikam | PRN: - 20070123120 | E&TC - B1

# %% [markdown]
# # Sum of Digits using Recursion

# %% [markdown]
# # Code

# %%
def func(n):
    if n==0:
        return 0
    else:
        return(n%10) +(func(n//10))
func(234837)
# Out:
# 27

# %% [markdown]
# # Algorithm

# %% [raw]
# 1. START.
# 2. Define func().
# 3. Break Number Digits.
# 4. Add the digits.
# 5. Return sum of digits.
# 6. STOP.

# %% [markdown]
# # FlowChart

# %% [markdown]
# ![Sum%20of%20Digits%20using%20Recursion.png](attachment:Sum%20of%20Digits%20using%20Recursion.png)
