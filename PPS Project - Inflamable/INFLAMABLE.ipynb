# %%
# INFLAMABLE CODE 


"""_____________________________________________________ZODIAC_____________________________________________________"""


def ZODIAC():
  print("\nWelcome to Zodiac Farm\n\n\n")
  day = int(input("Enter your Birth Day (DD)-"))
  month = input("Enter your Birth Month (month name)-")
  year = input("Enter your Birth Year (yyyy)-")
  print("\n\n!!!Almost There!!!")


  if day >= 22 and month == 'december':
    print("Your zodiac sign is - CAPRICON")
  elif day <= 20 and month == 'january':
    print("Your zodiac sign is - CAPRICON") 
  elif day >= 21 and month == 'january':
    print("Your zodiac sign is - AQUARIUS") 
  elif day <= 18 and month == 'february':
    print("Your zodiac sign is - AQUARIUS") 
  elif day >= 19 and month == 'february':
    print("Your zodiac sign is - PISCES")   
  elif day <= 20 and month == 'march':
    print("Your zodiac sign is - PISCES")   
  elif day >= 21 and month == 'march':
    print("Your zodiac sign is - ARIES")   
  elif day <= 20 and month == 'april':
    print("Your zodiac sign is - ARIES")   
  elif day >= 21 and month == 'appril':
    print("Your zodiac sign is - TAURUS") 
  elif day <= 21 and month == 'may':
    print("Your zodiac sign is - TAURUS")     
  elif day >= 22 and month == 'may':
    print("Your zodiac sign is - GEMINI") 
  elif day <= 21 and month == 'june':
    print("Your zodiac sign is - GEMINI") 
  elif day >= 22 and month == 'june':
    print("Your zodiac sign is - CANCER")       
  elif day <= 22 and month == 'july':
    print("Your zodiac sign is - CANCER")   
  elif day >= 23 and month == 'july':
    print("Your zodiac sign is - LEO")   
  elif day <= 23 and month == 'august':
    print("Your zodiac sign is - LEO")   
  elif day >= 24 and month == 'august':
    print("Your zodiac sign is - VIRGO") 
  elif day <= 22 and month == 'september':
    print("Your zodiac sign is - VIRGO")
  elif day >= 23 and month == 'september':
    print("Your zodiac sign is - LIBRA") 
  elif day <= 23 and month == 'october':
    print("Your zodiac sign is - LIBRA")
  elif day >= 24 and month == 'october':
    print("Your zodiac sign is - SCORPIO") 
  elif day <= 22 and month == 'november':
    print("Your zodiac sign is - SCORPIO") 
  elif day >= 23 and month == 'november':
    print("Your zodiac sign is - SAGITTARIUS") 
  elif day <= 21 and month == 'december':
    print("Your zodiac sign is - SAGITTARIUS")
    
  nextop = int(input("\nPress 1 for MAIN MENU and 0 for EXIT - "))
  if nextop == 1:
    MENU()
  elif nextop == 0:
    exit()      



"""_____________________________________________________LUCKYCOL___________________________________________________"""

def LUCKYCOL():
  print("WELCOME!\nLet's fetch your LUCKY COLOR!!\n\n")

  bdate=input('Enter your Birth Date (DDMMYYYY)-')
  print('\nSURFING THE RAINBOW TO FIND YOU......\n')

  tn=0
  for i in range(0,8):
    tn = int(bdate[i])+tn
  if tn < 10:
    num = tn
  else:
    num = int(tn/10) + tn%10
  if num >= 10:
    num=int(num / 10) + (num % 10)
  
  switch = { 1:'YELLOW & GOLD', 2:'BLUE AND WHITE', 3:'PURPLE', 4:'RED', 5:'ORANGE', 6:'GREEN', 7:'WHITE & PALE GREY', 8:'LIGHT BLUE', 9:'BROWN & MAROON' }

  print("HEY! Your LUCKY COLOR is/are - ",switch[num])


  nextop = int(input("\nPress 1 for MAIN MENU and 0 for EXIT - "))
  if nextop == 1:
    MENU()
  elif nextop == 0:
    exit()




"""___________________________________________________LUCKYNUM_____________________________________________________"""


def LUCKYNUM():
  print("\nWelcome! Let's find your LUCKY NUMBER\n\n")
  name=input('Enter your FIRST NAME - ')
  print("\nHey! {} , you got a nice name!\n\n".format(name))
  dd=int(input("Enter your Birth Day(DD)-"))
  mm=int(input("Enter your Birth Month(MM)-"))
  yyyy=input("Enter your Birth Year(YYYY)-")
  if dd < 10:
    d=dd;
  else:
    d=int((dd/10))+(dd%10)
  
  if mm < 10:
    m=mm;
  else:
    m=int((mm/10))+(mm%10)
  yt=0
  for i in range(0,4):
    yt=int(yyyy[i])+yt
  if yt<10:
    y=yt
  else:
    y=int((yt/10))+(yt%10) 
   
  temp = d + m + y 
  if temp < 10 :
    luckynum = d+m+y
  else:
    luckynum=int(((d+m+y)/10))+((d+m+y)%10)


  print("Your LUCKY NUMBER is - ",luckynum)
  
  nextop = int(input("\nPress 1 for MAIN MENU and 0 for EXIT - "))
  if nextop == 1:
    MENU()
  elif nextop == 0:
    exit()



"""__________________________________________________FLAMES_______________________________________________________"""
def FLAMES():
  print('\nWelcome to FLAMES....... \n!let us find how strings are attached!\n')

  name1=input('\n\nEnter your name - ')
  name2=input('Enter his/her name - ')

  print("\n\n\n!!!hold your breath !!!! we are almost there!!!\n\n\n")

  flames='flame'
  remains=[]

  if len(name1)>=len(name2):                      
    length=len(name2)
    for i in range(0,length):
      if name2[i] in name1:
        i+=1
        continue
      else:
        remains.append(name2[i])
        i+=1
    for j in range(0,len(name1)):
      if name1[j] in name2:
        j+=1
        continue
      else:
        remains.append(name1[j])
        j+=1  


  else:
    length=len(name1)
    for i in range(0,length):
      if name1[i] in name2:
        i+=1
        continue
      else:
        remains.append(name1[i])
        i+=1
  
    for j in range(0,len(name2)):
      if name2[j] in name1:
        j+=1
        continue
      else:
        remains.append(name2[j])    # remains-7
        j+=1                        #FLAME

  if len(remains)<=5:
    letter=flames[len(remains) - 1]   
  else:
    count=len(remains)
    while(count>5):
      count=len(remains)-5
    letter=flames[3 - count]    

  if letter=='f':
    print("You people are good FRIENDS!")
  elif letter=='l':
    print("Some one is blushing!!! your bond depicts LOVE :) ")  
  elif letter=='a':
    print("Guys! you people have some sort of AFFECTION amidst you....")
  elif letter=='m':
    print("Congrats! guys , you are gonna get MARRIED...")
  else:
    print("dude, sorry! you are EMOTIONALLY being fooled :( ...")   

  nextop = int(input("\nPress 1 for MAIN MENU and 0 for EXIT - "))
  if nextop == 1:
    MENU()
  elif nextop == 0:
    exit()      

"""_________________________________________________MENU___________________________________________________________"""  
  
def MENU():
  
  print("Welcome to INFLAMABLE\n\n")

  print("Press 1 for Playing FLAMES")
  print("Press 2 to know your LUCKY NUMBER")
  print("Press 3 to know your LUCKY COLOR")
  print("Press 4 to know your ZODIAC")
  print("Press 5 to know about the PROJECT TEAM")
  print("Press 6 to EXIT")

  opt=int(input("\nEnter your choice - "))

  if opt == 6:
    print("\n Thanks for visiting")
    exit()
  elif opt>6 or opt<1:
    while(opt>6 or opt<1):
      opt=int(input('\nKindly enter a VALID option-'))

  if opt == 1:
    FLAMES()
  elif opt == 2:
    LUCKYNUM()
  elif opt == 3:
    LUCKYCOL()
  elif opt == 4:
    ZODIAC()
  elif opt == 5:
    print("\nGreetings,\nThis project is comprised of 4 programes letting you walk through different games like-\n1-FLAMES\n2-LUCKY NUMBER\n3-LUCKY CLOLOR\n4-ZODIAC ")
    print("\nHope you liked the Project\nRegards\nTanishq(20070123119),\nParth(20070123120),\nYogesh(20070123121),\nPiya(20070123116),\nMahum(20070123117),\nHarshita(20070123122)") 
    nextop = int(input("\nPress 1 for MAIN MENU and 0 for EXIT - "))
    if nextop == 1:
      MENU()
    elif nextop == 0:
      exit()   

"""____________________________________________________EXECUTION______________________________________________________"""
  
MENU()
# Out:
# Welcome to INFLAMABLE
#
#
# Press 1 for Playing FLAMES
# Press 2 to know your LUCKY NUMBER
# Press 3 to know your LUCKY COLOR
# Press 4 to know your ZODIAC
# Press 5 to know about the PROJECT TEAM
# Press 6 to EXIT
#
# Enter your choice - 5
#
# Greetings,
# This project is comprised of 4 programes letting you walk through different games like-
# 1-FLAMES
# 2-LUCKY NUMBER
# 3-LUCKY CLOLOR
# 4-ZODIAC
#
# Hope you liked the Project
# Regards
# Tanishq(20070123119),
# Parth(20070123120),
# Yogesh(20070123121),
# Piya(20070123116),
# Mahum(20070123117),
# Harshita(20070123122)
